# %%
import pandas as pd
import numpy as np
df=pd.read_excel('/content/Amazon_Customer_Purchase_Data.xlsx')

# %%
df
# Out:
#       Customer_ID Customer_Name   Age  Gender       Location Product_Category  \
# 0           17270          John  56.0   Other       New York            Books
# 1           10860           Eve  33.0   Other        Houston  Home Appliances
# 2           15390          John  50.0  Female        Houston         Clothing
# 3           15191           Eve  66.0   Other  San Francisco      Electronics
# 4           15734           Eve  38.0  Female       New York             Toys
# ...           ...           ...   ...     ...            ...              ...
# 1995        10661       Charlie  61.0    Male    Los Angeles  Home Appliances
# 1996        13374           Eve  41.0  Female        Chicago            Books
# 1997        19208         Alice  58.0  Female        Houston             Toys
# 1998        10207          John  18.0  Female  San Francisco            Books
# 1999        12665         Alice  68.0   Other       New York         Clothing
#
#       Product_ID       Purchase_Date  Purchase_Amount Payment_Method  Rating  \
# 0            674 2020-01-01 00:00:00       491.643012           Cash     NaN
# 1            393 2020-01-01 01:00:00       144.326722           Cash     5.0
# 2            995 2020-01-01 02:00:00       109.301892  Bank Transfer     NaN
# 3            405 2020-01-01 03:00:00       226.655516  Bank Transfer     2.0
# 4            353 2020-01-01 04:00:00        37.851880  Bank Transfer     2.0
# ...          ...                 ...              ...            ...     ...
# 1995         989 2020-03-24 03:00:00       168.291356    Credit Card     5.0
# 1996         409 2020-03-24 04:00:00       237.252493  Bank Transfer     5.0
# 1997         617 2020-03-24 05:00:00       213.388283         PayPal     4.0
# 1998         113 2020-03-24 06:00:00        83.056883  Bank Transfer     2.0
# 1999         231 2020-03-24 07:00:00       479.331469         PayPal     2.0
#
#      Feedback_Comments  Customer_Lifetime_Value  Loyalty_Score  \
# 0                  NaN              3673.712747             60
# 1                 Good              2103.060388             29
# 2                  NaN               899.115059             92
# 3            Excellent              2591.137716             62
# 4                  NaN               548.620397             80
# ...                ...                      ...            ...
# 1995         Excellent              1058.502176              3
# 1996           Average              1581.739382             79
# 1997              Good              1155.797595             76
# 1998               NaN              1155.489570             32
# 1999               NaN              4752.340118             47
#
#      Discount_Applied Return_Status Customer_Segment  \
# 0                  No            No          Regular
# 1                 Yes           Yes              New
# 2                  No            No              VIP
# 3                 Yes           Yes          Regular
# 4                  No           Yes          Regular
# ...               ...           ...              ...
# 1995              Yes            No              New
# 1996              Yes            No          Regular
# 1997              Yes            No          Regular
# 1998               No            No              New
# 1999               No            No          Regular
#
#      Preferred_Shopping_Channel
# 0                      In-store
# 1                      In-store
# 2                        Online
# 3                        Online
# 4                          Both
# ...                         ...
# 1995                     Online
# 1996                     Online
# 1997                   In-store
# 1998                     Online
# 1999                     Online
#
# [2000 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Customer_ID                 2000 non-null   int64
#  1   Customer_Name               1900 non-null   object
#  2   Age                         1900 non-null   float64
#  3   Gender                      2000 non-null   object
#  4   Location                    2000 non-null   object
#  5   Product_Category            2000 non-null   object
#  6   Product_ID                  2000 non-null   int64
#  7   Purchase_Date               2000 non-null   datetime64[ns]
#  8   Purchase_Amount             1800 non-null   float64
#  9   Payment_Method              2000 non-null   object
#  10  Rating                      1860 non-null   float64
#  11  Feedback_Comments           1099 non-null   object
#  12  Customer_Lifetime_Value     1800 non-null   float64
#  13  Loyalty_Score               2000 non-null   int64
#  14  Discount_Applied            2000 non-null   object
#  15  Return_Status               2000 non-null   object
#  16  Customer_Segment            2000 non-null   object
#  17  Preferred_Shopping_Channel  2000 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(3), object(10)
# memory usage: 281.4+ KB

# %%
df.drop('Customer_Name', inplace=True, axis=1)

# %%
df.fillna(df.select_dtypes(['int64', 'float64']).mean(), inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Customer_ID                 2000 non-null   int64
#  1   Age                         2000 non-null   float64
#  2   Gender                      2000 non-null   object
#  3   Location                    2000 non-null   object
#  4   Product_Category            2000 non-null   object
#  5   Product_ID                  2000 non-null   int64
#  6   Purchase_Date               2000 non-null   datetime64[ns]
#  7   Purchase_Amount             2000 non-null   float64
#  8   Payment_Method              2000 non-null   object
#  9   Rating                      2000 non-null   float64
#  10  Feedback_Comments           1099 non-null   object
#  11  Customer_Lifetime_Value     2000 non-null   float64
#  12  Loyalty_Score               2000 non-null   int64
#  13  Discount_Applied            2000 non-null   object
#  14  Return_Status               2000 non-null   object
#  15  Customer_Segment            2000 non-null   object
#  16  Preferred_Shopping_Channel  2000 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(3), object(9)
# memory usage: 265.8+ KB

# %%
for i in df.select_dtypes('object').columns:
  df[i].fillna(df[i].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-63-3815325728.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[i].fillna(df[i].mode()[0], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Customer_ID                 2000 non-null   int64
#  1   Age                         2000 non-null   float64
#  2   Gender                      2000 non-null   object
#  3   Location                    2000 non-null   object
#  4   Product_Category            2000 non-null   object
#  5   Product_ID                  2000 non-null   int64
#  6   Purchase_Date               2000 non-null   datetime64[ns]
#  7   Purchase_Amount             2000 non-null   float64
#  8   Payment_Method              2000 non-null   object
#  9   Rating                      2000 non-null   float64
#  10  Feedback_Comments           2000 non-null   object
#  11  Customer_Lifetime_Value     2000 non-null   float64
#  12  Loyalty_Score               2000 non-null   int64
#  13  Discount_Applied            2000 non-null   object
#  14  Return_Status               2000 non-null   object
#  15  Customer_Segment            2000 non-null   object
#  16  Preferred_Shopping_Channel  2000 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(3), object(9)
# memory usage: 265.8+ KB

# %%
df.describe()
# Out:
#         Customer_ID          Age   Product_ID                  Purchase_Date  \
# count   2000.000000  2000.000000  2000.000000                           2000
# mean   15022.171500    43.696316   546.669000  2020-02-11 15:29:59.999999744
# min    10001.000000    18.000000   100.000000            2020-01-01 00:00:00
# 25%    12585.750000    32.000000   320.750000            2020-01-21 19:45:00
# 50%    15104.500000    43.696316   551.000000            2020-02-11 15:30:00
# 75%    17408.250000    56.000000   763.000000            2020-03-03 11:15:00
# max    19998.000000    69.000000   998.000000            2020-03-24 07:00:00
# std     2865.577794    14.525405   259.999847                            NaN
#
#        Purchase_Amount       Rating  Customer_Lifetime_Value  Loyalty_Score
# count      2000.000000  2000.000000              2000.000000     2000.00000
# mean        257.954370     2.978495              2566.724026       51.45700
# min          10.077295     1.000000                56.153142        1.00000
# 25%         151.383179     2.000000              1349.598107       26.00000
# 50%         257.954370     3.000000              2559.658142       52.00000
# 75%         367.247567     4.000000              3475.870962       76.00000
# max         499.839871     5.000000              7204.408434      100.00000
# std         134.915732     1.359225              1568.100325       28.74591

# %%
df['Purchase_Date'] = pd.to_datetime(df['Purchase_Date'])

# %%
df.head(15)
# Out:
#     Customer_ID   Age  Gender       Location Product_Category  Product_ID  \
# 0         17270  56.0   Other       New York            Books         674
# 1         10860  33.0   Other        Houston  Home Appliances         393
# 2         15390  50.0  Female        Houston         Clothing         995
# 3         15191  66.0   Other  San Francisco      Electronics         405
# 4         15734  38.0  Female       New York             Toys         353
# 5         16265  26.0   Other       New York         Clothing         279
# 6         10466  23.0  Female       New York         Clothing         139
# 7         14426  68.0   Other        Chicago            Books         875
# 8         15578  62.0   Other        Chicago      Electronics         800
# 9         18322  52.0    Male  San Francisco            Books         619
# 10        11685  56.0   Other       New York            Books         715
# 11        10769  39.0   Other       New York  Home Appliances         836
# 12        16949  58.0    Male        Houston             Toys         645
# 13        12433  22.0  Female        Houston         Clothing         335
# 14        15311  59.0    Male  San Francisco      Electronics         562
#
#          Purchase_Date  Purchase_Amount Payment_Method    Rating  \
# 0  2020-01-01 00:00:00       491.643012           Cash  2.978495
# 1  2020-01-01 01:00:00       144.326722           Cash  5.000000
# 2  2020-01-01 02:00:00       109.301892  Bank Transfer  2.978495
# 3  2020-01-01 03:00:00       226.655516  Bank Transfer  2.000000
# 4  2020-01-01 04:00:00        37.851880  Bank Transfer  2.000000
# 5  2020-01-01 05:00:00       489.462288         PayPal  3.000000
# 6  2020-01-01 06:00:00       298.332443         PayPal  4.000000
# 7  2020-01-01 07:00:00       282.906525  Bank Transfer  4.000000
# 8  2020-01-01 08:00:00       331.340177    Credit Card  2.000000
# 9  2020-01-01 09:00:00       253.541587    Credit Card  3.000000
# 10 2020-01-01 10:00:00        25.711123  Bank Transfer  2.000000
# 11 2020-01-01 11:00:00       310.032532         PayPal  4.000000
# 12 2020-01-01 12:00:00       360.925200         PayPal  5.000000
# 13 2020-01-01 13:00:00       214.207040    Credit Card  3.000000
# 14 2020-01-01 14:00:00       381.074830           Cash  2.978495
#
#    Feedback_Comments  Customer_Lifetime_Value  Loyalty_Score Discount_Applied  \
# 0               Good              3673.712747             60               No
# 1               Good              2103.060388             29              Yes
# 2               Good               899.115059             92               No
# 3          Excellent              2591.137716             62              Yes
# 4               Good               548.620397             80               No
# 5               Good              2727.555899             46               No
# 6               Good              3076.554423             26               No
# 7                Bad              3269.745729             28               No
# 8               Good              4319.156456             92              Yes
# 9            Average              3428.350802             59               No
# 10              Good               287.699980             55               No
# 11              Good              2346.345642             86              Yes
# 12           Average              4178.945237             90               No
# 13              Good              1697.167685             52               No
# 14              Good              3851.796963             27              Yes
#
#    Return_Status Customer_Segment Preferred_Shopping_Channel
# 0             No          Regular                   In-store
# 1            Yes              New                   In-store
# 2             No              VIP                     Online
# 3            Yes          Regular                     Online
# 4            Yes          Regular                       Both
# 5             No          Regular                     Online
# 6             No              New                       Both
# 7             No              New                     Online
# 8             No              VIP                     Online
# 9             No          Regular                       Both
# 10            No          Regular                     Online
# 11            No              VIP                   In-store
# 12            No              VIP                     Online
# 13           Yes          Regular                     Online
# 14           Yes              New                   In-store

# %%
for i in df.select_dtypes('object').columns:
  print(f"{i} distibution is")
  print('-------------------------')
  print(df[i].value_counts())
  print("============================================")
# Out:
# Gender distibution is
# -------------------------
# Gender
# Female    687
# Male      662
# Other     651
# Name: count, dtype: int64
# ============================================
# Location distibution is
# -------------------------
# Location
# New York         434
# San Francisco    430
# Los Angeles      381
# Chicago          379
# Houston          376
# Name: count, dtype: int64
# ============================================
# Product_Category distibution is
# -------------------------
# Product_Category
# Toys               437
# Home Appliances    397
# Electronics        395
# Books              392
# Clothing           379
# Name: count, dtype: int64
# ============================================
# Payment_Method distibution is
# -------------------------
# Payment_Method
# Credit Card      509
# Cash             506
# PayPal           501
# Bank Transfer    484
# Name: count, dtype: int64
# ============================================
# Feedback_Comments distibution is
# -------------------------
# Feedback_Comments
# Good         1191
# Excellent     271
# Average       270
# Bad           268
# Name: count, dtype: int64
# ============================================
# Discount_Applied distibution is
# -------------------------
# Discount_Applied
# No     1397
# Yes     603
# Name: count, dtype: int64
# ============================================
# Return_Status distibution is
# -------------------------
# Return_Status
# No     1588
# Yes     412
# Name: count, dtype: int64
# ============================================
# Customer_Segment distibution is
# -------------------------
# Customer_Segment
# Regular    824
# New        767
# VIP        409
# Name: count, dtype: int64
# ============================================
# Preferred_Shopping_Channel distibution is
# -------------------------
# Preferred_Shopping_Channel
# Online      999
# In-store    603
# Both        398
# Name: count, dtype: int64
# ============================================

# %%
#for outlier detection
import matplotlib.pyplot as plt
import seaborn as sns
for i in ['Purchase_Amount','Customer_Lifetime_Value']:
  plt.figure(figsize=(3,3))
  sns.boxplot(y = i, data= df)

# %%
#outlier treatment for Purchase amount and CLV
for i in ['Purchase_Amount','Customer_Lifetime_Value']:
  Q1=df[i].quantile(0.25)
  Q3=df[i].quantile(0.75)
  IQR=Q3-Q1
  lower=Q1-(1.5*IQR)
  upper=Q3+(1.5*IQR)
  med=df[i].median()
  df[i]=np.where((df[i]<lower) | (df[i]>upper),med,df[i])
  print(i,lower,upper)
# Out:
# Purchase_Amount -172.41340396068006 691.0441496406538
# Customer_Lifetime_Value -1839.8111759100252 6665.280244840902

# %%
# Droping the unuseful column
df.drop_duplicates(subset=['Customer_ID', 'Purchase_Date'], inplace=True)

# %%
df
# Out:
#       Customer_ID   Age  Gender       Location Product_Category  Product_ID  \
# 0           17270  56.0   Other       New York            Books         674
# 1           10860  33.0   Other        Houston  Home Appliances         393
# 2           15390  50.0  Female        Houston         Clothing         995
# 3           15191  66.0   Other  San Francisco      Electronics         405
# 4           15734  38.0  Female       New York             Toys         353
# ...           ...   ...     ...            ...              ...         ...
# 1995        10661  61.0    Male    Los Angeles  Home Appliances         989
# 1996        13374  41.0  Female        Chicago            Books         409
# 1997        19208  58.0  Female        Houston             Toys         617
# 1998        10207  18.0  Female  San Francisco            Books         113
# 1999        12665  68.0   Other       New York         Clothing         231
#
#            Purchase_Date  Purchase_Amount Payment_Method    Rating  \
# 0    2020-01-01 00:00:00       491.643012           Cash  2.978495
# 1    2020-01-01 01:00:00       144.326722           Cash  5.000000
# 2    2020-01-01 02:00:00       109.301892  Bank Transfer  2.978495
# 3    2020-01-01 03:00:00       226.655516  Bank Transfer  2.000000
# 4    2020-01-01 04:00:00        37.851880  Bank Transfer  2.000000
# ...                  ...              ...            ...       ...
# 1995 2020-03-24 03:00:00       168.291356    Credit Card  5.000000
# 1996 2020-03-24 04:00:00       237.252493  Bank Transfer  5.000000
# 1997 2020-03-24 05:00:00       213.388283         PayPal  4.000000
# 1998 2020-03-24 06:00:00        83.056883  Bank Transfer  2.000000
# 1999 2020-03-24 07:00:00       479.331469         PayPal  2.000000
#
#      Feedback_Comments  Customer_Lifetime_Value  Loyalty_Score  \
# 0                 Good              3673.712747             60
# 1                 Good              2103.060388             29
# 2                 Good               899.115059             92
# 3            Excellent              2591.137716             62
# 4                 Good               548.620397             80
# ...                ...                      ...            ...
# 1995         Excellent              1058.502176              3
# 1996           Average              1581.739382             79
# 1997              Good              1155.797595             76
# 1998              Good              1155.489570             32
# 1999              Good              4752.340118             47
#
#      Discount_Applied Return_Status Customer_Segment  \
# 0                  No            No          Regular
# 1                 Yes           Yes              New
# 2                  No            No              VIP
# 3                 Yes           Yes          Regular
# 4                  No           Yes          Regular
# ...               ...           ...              ...
# 1995              Yes            No              New
# 1996              Yes            No          Regular
# 1997              Yes            No          Regular
# 1998               No            No              New
# 1999               No            No          Regular
#
#      Preferred_Shopping_Channel
# 0                      In-store
# 1                      In-store
# 2                        Online
# 3                        Online
# 4                          Both
# ...                         ...
# 1995                     Online
# 1996                     Online
# 1997                   In-store
# 1998                     Online
# 1999                     Online
#
# [2000 rows x 17 columns]

# %%
df['Rating'] = df['Rating'].round(0).astype(int)
df.head()
# Out:
#    Customer_ID   Age  Gender       Location Product_Category  Product_ID  \
# 0        17270  56.0   Other       New York            Books         674
# 1        10860  33.0   Other        Houston  Home Appliances         393
# 2        15390  50.0  Female        Houston         Clothing         995
# 3        15191  66.0   Other  San Francisco      Electronics         405
# 4        15734  38.0  Female       New York             Toys         353
#
#         Purchase_Date  Purchase_Amount Payment_Method  Rating  \
# 0 2020-01-01 00:00:00       491.643012           Cash       3
# 1 2020-01-01 01:00:00       144.326722           Cash       5
# 2 2020-01-01 02:00:00       109.301892  Bank Transfer       3
# 3 2020-01-01 03:00:00       226.655516  Bank Transfer       2
# 4 2020-01-01 04:00:00        37.851880  Bank Transfer       2
#
#   Feedback_Comments  Customer_Lifetime_Value  Loyalty_Score Discount_Applied  \
# 0              Good              3673.712747             60               No
# 1              Good              2103.060388             29              Yes
# 2              Good               899.115059             92               No
# 3         Excellent              2591.137716             62              Yes
# 4              Good               548.620397             80               No
#
#   Return_Status Customer_Segment Preferred_Shopping_Channel
# 0            No          Regular                   In-store
# 1           Yes              New                   In-store
# 2            No              VIP                     Online
# 3           Yes          Regular                     Online
# 4           Yes          Regular                       Both

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Customer_ID                 2000 non-null   int64
#  1   Age                         2000 non-null   float64
#  2   Gender                      2000 non-null   object
#  3   Location                    2000 non-null   object
#  4   Product_Category            2000 non-null   object
#  5   Product_ID                  2000 non-null   int64
#  6   Purchase_Date               2000 non-null   datetime64[ns]
#  7   Purchase_Amount             2000 non-null   float64
#  8   Payment_Method              2000 non-null   object
#  9   Rating                      2000 non-null   int64
#  10  Feedback_Comments           2000 non-null   object
#  11  Customer_Lifetime_Value     2000 non-null   float64
#  12  Loyalty_Score               2000 non-null   int64
#  13  Discount_Applied            2000 non-null   object
#  14  Return_Status               2000 non-null   object
#  15  Customer_Segment            2000 non-null   object
#  16  Preferred_Shopping_Channel  2000 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(4), object(9)
# memory usage: 265.8+ KB

# %%
# Projected Customer_Lifetime_Value (CLV)
df['CLV_Estimated'] = (df['Customer_Lifetime_Value'] * df['Loyalty_Score']) / 100
df.head()
# Out:
#    Customer_ID   Age  Gender       Location Product_Category  Product_ID  \
# 0        17270  56.0   Other       New York            Books         674
# 1        10860  33.0   Other        Houston  Home Appliances         393
# 2        15390  50.0  Female        Houston         Clothing         995
# 3        15191  66.0   Other  San Francisco      Electronics         405
# 4        15734  38.0  Female       New York             Toys         353
#
#         Purchase_Date  Purchase_Amount Payment_Method  Rating  \
# 0 2020-01-01 00:00:00       491.643012           Cash       3
# 1 2020-01-01 01:00:00       144.326722           Cash       5
# 2 2020-01-01 02:00:00       109.301892  Bank Transfer       3
# 3 2020-01-01 03:00:00       226.655516  Bank Transfer       2
# 4 2020-01-01 04:00:00        37.851880  Bank Transfer       2
#
#   Feedback_Comments  Customer_Lifetime_Value  Loyalty_Score Discount_Applied  \
# 0              Good              3673.712747             60               No
# 1              Good              2103.060388             29              Yes
# 2              Good               899.115059             92               No
# 3         Excellent              2591.137716             62              Yes
# 4              Good               548.620397             80               No
#
#   Return_Status Customer_Segment Preferred_Shopping_Channel  CLV_Estimated
# 0            No          Regular                   In-store    2204.227648
# 1           Yes              New                   In-store     609.887513
# 2            No              VIP                     Online     827.185854
# 3           Yes          Regular                     Online    1606.505384
# 4           Yes          Regular                       Both     438.896318

# %%
# Loyalty Score
df['Loyalty_Score_Enhanced'] = ((df['Purchase_Amount'] / df['Purchase_Amount'].max()) * 50 + (df['Rating'] / df['Rating'].max()) * 50).round().astype(int)
df.head()
# Out:
#    Customer_ID   Age  Gender       Location Product_Category  Product_ID  \
# 0        17270  56.0   Other       New York            Books         674
# 1        10860  33.0   Other        Houston  Home Appliances         393
# 2        15390  50.0  Female        Houston         Clothing         995
# 3        15191  66.0   Other  San Francisco      Electronics         405
# 4        15734  38.0  Female       New York             Toys         353
#
#         Purchase_Date  Purchase_Amount Payment_Method  Rating  \
# 0 2020-01-01 00:00:00       491.643012           Cash       3
# 1 2020-01-01 01:00:00       144.326722           Cash       5
# 2 2020-01-01 02:00:00       109.301892  Bank Transfer       3
# 3 2020-01-01 03:00:00       226.655516  Bank Transfer       2
# 4 2020-01-01 04:00:00        37.851880  Bank Transfer       2
#
#   Feedback_Comments  Customer_Lifetime_Value  Loyalty_Score Discount_Applied  \
# 0              Good              3673.712747             60               No
# 1              Good              2103.060388             29              Yes
# 2              Good               899.115059             92               No
# 3         Excellent              2591.137716             62              Yes
# 4              Good               548.620397             80               No
#
#   Return_Status Customer_Segment Preferred_Shopping_Channel  CLV_Estimated  \
# 0            No          Regular                   In-store    2204.227648
# 1           Yes              New                   In-store     609.887513
# 2            No              VIP                     Online     827.185854
# 3           Yes          Regular                     Online    1606.505384
# 4           Yes          Regular                       Both     438.896318
#
#    Loyalty_Score_Enhanced
# 0                      79
# 1                      64
# 2                      41
# 3                      43
# 4                      24

# %%
# Customer Segment
df['Customer_Segment_Label'] = pd.cut( df['Loyalty_Score'], bins=[0, 39, 74, 100], labels=['New', 'Regular', 'VIP'])
df.head()
# Out:
#    Customer_ID   Age  Gender       Location Product_Category  Product_ID  \
# 0        17270  56.0   Other       New York            Books         674
# 1        10860  33.0   Other        Houston  Home Appliances         393
# 2        15390  50.0  Female        Houston         Clothing         995
# 3        15191  66.0   Other  San Francisco      Electronics         405
# 4        15734  38.0  Female       New York             Toys         353
#
#         Purchase_Date  Purchase_Amount Payment_Method  Rating  \
# 0 2020-01-01 00:00:00       491.643012           Cash       3
# 1 2020-01-01 01:00:00       144.326722           Cash       5
# 2 2020-01-01 02:00:00       109.301892  Bank Transfer       3
# 3 2020-01-01 03:00:00       226.655516  Bank Transfer       2
# 4 2020-01-01 04:00:00        37.851880  Bank Transfer       2
#
#   Feedback_Comments  Customer_Lifetime_Value  Loyalty_Score Discount_Applied  \
# 0              Good              3673.712747             60               No
# 1              Good              2103.060388             29              Yes
# 2              Good               899.115059             92               No
# 3         Excellent              2591.137716             62              Yes
# 4              Good               548.620397             80               No
#
#   Return_Status Customer_Segment Preferred_Shopping_Channel  CLV_Estimated  \
# 0            No          Regular                   In-store    2204.227648
# 1           Yes              New                   In-store     609.887513
# 2            No              VIP                     Online     827.185854
# 3           Yes          Regular                     Online    1606.505384
# 4           Yes          Regular                       Both     438.896318
#
#    Loyalty_Score_Enhanced Customer_Segment_Label
# 0                      79                Regular
# 1                      64                    New
# 2                      41                    VIP
# 3                      43                Regular
# 4                      24                    VIP

# %%
df.head()
# Out:
#    Customer_ID   Age  Gender       Location Product_Category  Product_ID  \
# 0        17270  56.0   Other       New York            Books         674
# 1        10860  33.0   Other        Houston  Home Appliances         393
# 2        15390  50.0  Female        Houston         Clothing         995
# 3        15191  66.0   Other  San Francisco      Electronics         405
# 4        15734  38.0  Female       New York             Toys         353
#
#         Purchase_Date  Purchase_Amount Payment_Method  Rating  \
# 0 2020-01-01 00:00:00       491.643012           Cash       3
# 1 2020-01-01 01:00:00       144.326722           Cash       5
# 2 2020-01-01 02:00:00       109.301892  Bank Transfer       3
# 3 2020-01-01 03:00:00       226.655516  Bank Transfer       2
# 4 2020-01-01 04:00:00        37.851880  Bank Transfer       2
#
#   Feedback_Comments  Customer_Lifetime_Value  Loyalty_Score Discount_Applied  \
# 0              Good              3673.712747             60               No
# 1              Good              2103.060388             29              Yes
# 2              Good               899.115059             92               No
# 3         Excellent              2591.137716             62              Yes
# 4              Good               548.620397             80               No
#
#   Return_Status Customer_Segment Preferred_Shopping_Channel  CLV_Estimated  \
# 0            No          Regular                   In-store    2204.227648
# 1           Yes              New                   In-store     609.887513
# 2            No              VIP                     Online     827.185854
# 3           Yes          Regular                     Online    1606.505384
# 4           Yes          Regular                       Both     438.896318
#
#    Loyalty_Score_Enhanced Customer_Segment_Label
# 0                      79                Regular
# 1                      64                    New
# 2                      41                    VIP
# 3                      43                Regular
# 4                      24                    VIP

# %%
df.to_excel('/content/VisualizationData.xlsx', index=False)
